# %% [markdown]
# <h1>Sales of Games Analysis</h1>
# <p>A few analysis using the <a href="https://www.kaggle.com/gregorut/videogamesales">videogamesales dataset</a> located at kaggle.</p>
# Based on the <a href="https://paulovasconcellos.com.br/como-criar-seu-primeiro-projeto-de-data-science-parte-2-de-2-cb9a2fe05eff">tutorial</a> made by Paulo Vasconcellos.
# <br>
# <p>Created by: <i>Ana Julia Bravo</i></p>
# <br>
# <img src="https://img.itch.zone/aW1hZ2UvODg0NzQvNDI3NTE3LmdpZg==/147x117%23/kY7cth.gif" align="center">

# %%
#gráficos gerados sejam mostrados dentro do notebook
# %matplotlib inline

# %%
#importar bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#definição do estilo dos gráficos
plt.style.use('ggplot')

# %%
#carregar dataset na memoria
videogames = pd.read_csv('C:/Users/Usuario/Downloads/videogamesales/vgsales.csv')

# %%
#exibir 10 primeiras linhas do dataframe
videogames.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
#resumo das infos em todas as colunas
videogames.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
#tipo de dados de cada coluna
 #no pandas, string é object
videogames.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#comando shape (pandas): retorna uma tupla : qtd de linhas e qtd de colunas da nossa tabela
videogames.shape
# Out:
# (16598, 11)

# %%
#renomeia colunas
videogames.columns = ['Ranking', 'Nome', 'Plataforma', 'Ano', 'Gênero', 'Editora', 'Vendas América do Norte', 'Vendas EUA', 'Vendas Japão', 'Outras vendas', 'Vendas Global']

# %%
#verificar nome das colunas
videogames.head(10)
# Out:
#    Ranking                       Nome Plataforma     Ano        Gênero  \
# 0        1                 Wii Sports        Wii  2006.0        Sports
# 1        2          Super Mario Bros.        NES  1985.0      Platform
# 2        3             Mario Kart Wii        Wii  2008.0        Racing
# 3        4          Wii Sports Resort        Wii  2009.0        Sports
# 4        5   Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
# 5        6                     Tetris         GB  1989.0        Puzzle
# 6        7      New Super Mario Bros.         DS  2006.0      Platform
# 7        8                   Wii Play        Wii  2006.0          Misc
# 8        9  New Super Mario Bros. Wii        Wii  2009.0      Platform
# 9       10                  Duck Hunt        NES  1984.0       Shooter
#
#     Editora  Vendas América do Norte  Vendas EUA  Vendas Japão  Outras vendas  \
# 0  Nintendo                    41.49       29.02          3.77           8.46
# ...

# %% [markdown]
# <h3>Tratando valores nulos</h3>
# <p>Quando estamos realizando análises em dados, frequentemente iremos esbarrar em valores nulos. Tratam-se de campos que não tiveram um valor informado e, para que não fique um espaço vazio no seu DataFrame e, consequentemente gere um erro, o pandas insere o valor NaN.</p>
# <p>A função isnull() do pandas permite trabalhar com valores nulos.</p>

# %%
#para encontrar os valores nulos da tabela 'Ano'
videogames[videogames['Ano'].isnull()].head
# Out:
# <bound method NDFrame.head of        Ranking                                         Nome Plataforma  Ano  \
# 179        180                              Madden NFL 2004        PS2  NaN
# 377        378                             FIFA Soccer 2004        PS2  NaN
# 431        432                   LEGO Batman: The Videogame        Wii  NaN
# 470        471                   wwe Smackdown vs. Raw 2006        PS2  NaN
# 607        608                               Space Invaders       2600  NaN
# 624        625                                    Rock Band       X360  NaN
# 649        650     Frogger's Adventures: Temple of the Frog        GBA  NaN
# 652        653  LEGO Indiana Jones: The Original Adventures        Wii  NaN
# 711        713                               Call of Duty 3        Wii  NaN
# 782        784                                    Rock Band        Wii  NaN
# 1126      1128                      Call of Duty: Black Ops         PC  NaN
# ...

# %% [markdown]
# <h3>Visualizando os dados</h3>
# <p>Utiliza-se a criação de gráficos para uma melhor visualização dos dados.</p>
# <p>Vamos utilizar as bibliotecas 'matplotlib' e 'seaborn'.</p>

# %%
#para ver a qtd
videogames['Plataforma'].value_counts()
    #qts jogos foram lançados para cada plataforma, ordenados do maior para menor
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Plataforma, dtype: int64

# %%
#duas formas de contar valores em coluna:

    #1 - em duas linhas
titulos_lancados = videogames['Plataforma'].value_counts()
titulos_lancados.plot()
    #2 - em uma linha
videogames['Plataforma'].value_counts().plot()

# %% [markdown]
# <h3>Função plot()</h3>
# <p>Cria, por padrão, um gráfico de linha utilizando o index como eixo X [horiz] e valores da contagem no eixo Y</p>
#
# <h4>Argumentos da função plot()</h4>
# <p>
#     <ul>
#         <li>kind: informa o tipo de gráfico que queremos criar. Ex.: um gráfico de barras: "bar";</li>
#         <li>figsize: informa o tamanho que nosso gráfico terá. Esse valor precisa ser passado em forma de tupla — entre parenteses;</li>
#         <li>grid: diz se nós queremos que apareça linhas de grade em nosso gráfico. Dependendo da situação, eles são muito úteis, mas aqui não será necessário, portanto, eu informo o valor False;</li>
#         <li>rot: informa o grau de rotação que nossos dados do eixo X devem ter. Como eu quero que os valores sejam apresentados em linha reta sem inclinação, eu coloquei o valor 0;</li>
#         <li>color: a cor do gráfico. Dependendo do tipo de gráfico, você pode informar mais de uma cor em formato de lista, por exemplo: ['green', 'red', 'blue']. Eu quero que meu gráfico tenha apenas a cor verde, eu coloco o valor 'green'.</li>
#     </ul>
# </p>

# %%
#criando um gráfico de barras
videogames['Plataforma'].value_counts().head(10).plot(kind='bar', figsize=(11,5), grid=False, rot=0, color='green')

#melhorando o gráfico, usando funções da biblioteca matplotlib
plt.title('Os 10 Videogames com mais Títulos Lançados') #titulo do gráfico
plt.xlabel('Videogame') #nome do eixo X
plt.ylabel('Quantidade de jogos lançados') #nome eixo Y
plt.show #mostrando o gráfico

#plt.show(): função para exibir o gráfico na célula abaixo. Mesmo que você não a digite, 
    #o gráfico será mostrado, contudo, isso facilita a leitura do código e 
        #evita que algumas informações inúteis sejam apresentadas na célula, como o tipo de dado do gráfico.
# Out:
# <function matplotlib.pyplot.show>

# %%
#descobrindo maior e menor valor de uma coluna
anomin = videogames['Ano'].min()

anomax = videogames['Ano'].max()

print(anomin, anomax)
# Out:
# 1980.0 2020.0

# %%
#Gráfico - 10 Jogos mais Vendidos
top10vendidos = videogames[['Nome', 'Vendas Global']].head(10).set_index('Nome').sort_values('Vendas Global', ascending=True)
graftop10 = top10vendidos.plot(kind='barh', figsize=(11,7), grid=False, color='darkred')
graftop10.legend(loc='upper center', bbox_to_anchor=(1.20, 0.7), shadow=True, ncol=1)

plt.title('Os 10 Jogos Mais Vendidos no Mundo entre ' + format(anomin) + ' e ' + format(anomax))
plt.xlabel('Total de vendas (em milhões de dólares)')
plt.show()

# %%
#Heatmap - gráfico que irá realçar frequências mais altas com cores mais escuras
   # Criando um novo DataFrame que contém informações cruzadas sobre o gênero do jogo e o console para o qual ele foi lançado
       #usando a função crosstab do pandas
crosstab_vg = pd.crosstab(videogames['Plataforma'], videogames['Gênero'])
crosstab_vg.head()
# Out:
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            182         37        14    53        28      20      11
# DC               3         11        12     0         2       0       6
# DS             343        240        36   393        92     238      67
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy
# Plataforma
# 2600                   0       24           1      12         0
# 3DO                    0        0           1       0         0
# 3DS                   86        7          30      26        15
# DC                     4        3           1      10         0
# DS                   200       42         285     148        79

# %%
#Adiconando a coluna Total: soma de todos os jogos lançados para cada console
crosstab_vg['Total'] = crosstab_vg.sum(axis=1)
crosstab_vg.head()
# Out:
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            182         37        14    53        28      20      11
# DC               3         11        12     0         2       0       6
# DS             343        240        36   393        92     238      67
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy  Total
# Plataforma
# 2600                   0       24           1      12         0    133
# 3DO                    0        0           1       0         0      3
# 3DS                   86        7          30      26        15    509
# DC                     4        3           1      10         0     52
# DS                   200       42         285     148        79   2163

# %%
#Heatmap - qtd de jogos lançados para cada gênero em cada plataforma
top10plat = crosstab_vg[crosstab_vg['Total']>1000].sort_values('Total', ascending=False)
top10final = top10plat.append(pd.DataFrame(top10plat.sum(), columns=['total']).T, ignore_index=False)


sns.set(font_scale=1) #define o tamanho da fonte a ser utilizada no gráfico

plt.figure(figsize=(18, 9)) #define o tamanho da figura do gráfico

sns.heatmap(top10final, annot=True, vmax=top10final.loc[:'PS', :'Strategy'].values.max(), vmin=top10final.loc[:, :'Strategy'].values.min(), fmt='d')

#Primeiro, utiliza-se o heatmap do seaborn. Essa função possui muitos argumentos que podem ser utilizados para personalizar seu gráfico, mas vou me ater aos mais importantes. O primeiro deles é o dado para exibir no gráfico, em nosso caso, o DataFrame top10_final. Em seguida eu informo o argumento annot=True, que faz com que os números de cada “quadradinho” apareça, facilitando a exibição. Se você definir esse valor para False, seu mapa de calor terá apenas as cores, sem qualquer número nelas.
    #annot=True --> aparecer os nrs de cada quadradinho
    #Para localizar os valores máximo e mínimo, eu utilizo a função .loc do pandas e filtro as linhas e colunas do DataFrame para localizar seus valores. 
    #argumento fmt='d' para formatar as informações para que fiquem bem apresentadas

plt.xlabel('Gênero')
plt.ylabel('Console')
plt.title('Quantidade de Títulos por Gênero e Console')
plt.show()
